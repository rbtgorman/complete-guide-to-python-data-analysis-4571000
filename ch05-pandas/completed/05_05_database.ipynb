# %% [markdown]
# # 05_05: Database operations in pandas

# %%
import math
import collections
import dataclasses
import datetime

import numpy as np
import pandas as pd
import matplotlib.pyplot as pp

# %%
actors = pd.read_csv('actors.csv', dtype_backend='pyarrow')

# %%
actresses = pd.read_csv('actresses.csv', dtype_backend='pyarrow')

# %%
actors.head(5)
# Out:
#    year_ceremony category                film                 name
# 0           1928    ACTOR    The Last Command        Emil Jannings
# 1           1928    ACTOR           The Noose  Richard Barthelmess
# 2           1929    ACTOR               Alibi       Chester Morris
# 3           1929    ACTOR      In Old Arizona        Warner Baxter
# 4           1929    ACTOR  The Patriot (1928)          Lewis Stone

# %%
actors.tail(10)
# Out:
#      year_ceremony                    category                        film  \
# 902           2024     ACTOR IN A LEADING ROLE            American Fiction
# 903           2024  ACTOR IN A SUPPORTING ROLE            American Fiction
# 904           2024  ACTOR IN A SUPPORTING ROLE                      Barbie
# 905           2024  ACTOR IN A SUPPORTING ROLE  Killers of the Flower Moon
# 906           2024     ACTOR IN A LEADING ROLE              Maestro (2023)
# 907           2024     ACTOR IN A LEADING ROLE                 Oppenheimer
# 908           2024  ACTOR IN A SUPPORTING ROLE                 Oppenheimer
# 909           2024  ACTOR IN A SUPPORTING ROLE                 Poor Things
# 910           2024     ACTOR IN A LEADING ROLE                      Rustin
# 911           2024     ACTOR IN A LEADING ROLE               The Holdovers
#
#                   name
# 902     Jeffrey Wright
# 903  Sterling K. Brown
# 904       Ryan Gosling
# 905     Robert De Niro
# 906     Bradley Cooper
# 907     Cillian Murphy
# 908  Robert Downey Jr.
# 909       Mark Ruffalo
# 910     Colman Domingo
# 911      Paul Giamatti

# %%
actresses.head(5)
# Out:
#    year_ceremony category             film             name
# 0           1928  ACTRESS       7th Heaven     Janet Gaynor
# 1           1928  ACTRESS  A Ship Comes In   Louise Dresser
# 2           1928  ACTRESS   Sadie Thompson   Gloria Swanson
# 3           1929  ACTRESS         Coquette    Mary Pickford
# 4           1929  ACTRESS         Madame X  Ruth Chatterton

# %%
pd.concat([actors, actresses])
# Out:
#      year_ceremony                      category                     film  \
# 0             1928                         ACTOR         The Last Command
# 1             1928                         ACTOR                The Noose
# 2             1929                         ACTOR                    Alibi
# 3             1929                         ACTOR           In Old Arizona
# 4             1929                         ACTOR       The Patriot (1928)
# ..             ...                           ...                      ...
# 911           2024  ACTRESS IN A SUPPORTING ROLE                     Nyad
# 912           2024  ACTRESS IN A SUPPORTING ROLE              Oppenheimer
# 913           2024     ACTRESS IN A LEADING ROLE              Poor Things
# 914           2024  ACTRESS IN A SUPPORTING ROLE  The Color Purple (2023)
# 915           2024  ACTRESS IN A SUPPORTING ROLE            The Holdovers
#
#                      name
# 0           Emil Jannings
# 1     Richard Barthelmess
# 2          Chester Morris
# 3           Warner Baxter
# 4             Lewis Stone
# ..                    ...
# 911          Jodie Foster
# 912           Emily Blunt
# 913            Emma Stone
# 914       Danielle Brooks
# 915  Da'Vine Joy Randolph
#
# [1828 rows x 4 columns]

# %%
nominations = pd.concat([actors, actresses]).sort_values(['year_ceremony', 'category']).reset_index(drop=True)

# %%
nominations
# Out:
#       year_ceremony                      category                     film  \
# 0              1928                         ACTOR         The Last Command
# 1              1928                         ACTOR                The Noose
# 2              1928                       ACTRESS               7th Heaven
# 3              1928                       ACTRESS          A Ship Comes In
# 4              1928                       ACTRESS           Sadie Thompson
# ...             ...                           ...                      ...
# 1823           2024  ACTRESS IN A SUPPORTING ROLE                   Barbie
# 1824           2024  ACTRESS IN A SUPPORTING ROLE                     Nyad
# 1825           2024  ACTRESS IN A SUPPORTING ROLE              Oppenheimer
# 1826           2024  ACTRESS IN A SUPPORTING ROLE  The Color Purple (2023)
# 1827           2024  ACTRESS IN A SUPPORTING ROLE            The Holdovers
#
#                       name
# 0            Emil Jannings
# 1      Richard Barthelmess
# 2             Janet Gaynor
# 3           Louise Dresser
# 4           Gloria Swanson
# ...                    ...
# 1823       America Ferrera
# 1824          Jodie Foster
# 1825           Emily Blunt
# 1826       Danielle Brooks
# 1827  Da'Vine Joy Randolph
#
# [1828 rows x 4 columns]

# %%
movies = pd.read_csv('movies.csv', dtype_backend='pyarrow')

# %%
movies.head()
# Out:
#                         film  year_film
# 0            $1,000 a Minute       1935
# 1                       '38'       1986
# 2         'Crocodile' Dundee       1986
# 3            'Round Midnight       1986
# 4  (A) Torzija [(A) Torsion]       2003

# %%
pd.merge(nominations, movies, on='film')
# Out:
#       year_ceremony                      category                     film  \
# 0              1928                         ACTOR         The Last Command
# 1              1928                         ACTOR                The Noose
# 2              1928                       ACTRESS               7th Heaven
# 3              1928                       ACTRESS          A Ship Comes In
# 4              1928                       ACTRESS           Sadie Thompson
# ...             ...                           ...                      ...
# 1823           2024  ACTRESS IN A SUPPORTING ROLE                   Barbie
# 1824           2024  ACTRESS IN A SUPPORTING ROLE                     Nyad
# 1825           2024  ACTRESS IN A SUPPORTING ROLE              Oppenheimer
# 1826           2024  ACTRESS IN A SUPPORTING ROLE  The Color Purple (2023)
# 1827           2024  ACTRESS IN A SUPPORTING ROLE            The Holdovers
#
#                       name  year_film
# 0            Emil Jannings       1927
# 1      Richard Barthelmess       1927
# 2             Janet Gaynor       1927
# 3           Louise Dresser       1927
# 4           Gloria Swanson       1927
# ...                    ...        ...
# 1823       America Ferrera       2023
# 1824          Jodie Foster       2023
# 1825           Emily Blunt       2023
# 1826       Danielle Brooks       2023
# 1827  Da'Vine Joy Randolph       2023
#
# [1828 rows x 5 columns]

# %%
pd.merge(nominations, movies.iloc[:3000], on='film')
# Out:
#       year_ceremony                      category             film  \
# 0              1928                       ACTRESS       7th Heaven
# 1              1928                       ACTRESS  A Ship Comes In
# 2              1929                         ACTOR            Alibi
# 3              1929                         ACTOR   In Old Arizona
# 4              1929                       ACTRESS         Coquette
# ...             ...                           ...              ...
# 1090           2024     ACTRESS IN A LEADING ROLE             Nyad
# 1091           2024     ACTRESS IN A LEADING ROLE      Poor Things
# 1092           2024  ACTRESS IN A SUPPORTING ROLE           Barbie
# 1093           2024  ACTRESS IN A SUPPORTING ROLE             Nyad
# 1094           2024  ACTRESS IN A SUPPORTING ROLE      Oppenheimer
#
#                  name  year_film
# 0        Janet Gaynor       1927
# 1      Louise Dresser       1927
# 2      Chester Morris       1928
# 3       Warner Baxter       1928
# 4       Mary Pickford       1928
# ...               ...        ...
# 1090   Annette Bening       2023
# 1091       Emma Stone       2023
# 1092  America Ferrera       2023
# 1093     Jodie Foster       2023
# 1094      Emily Blunt       2023
#
# [1095 rows x 5 columns]

# %%
pd.merge(nominations, movies.iloc[:3000], on='film', how='left')
# Out:
#       year_ceremony                      category                     film  \
# 0              1928                         ACTOR         The Last Command
# 1              1928                         ACTOR                The Noose
# 2              1928                       ACTRESS               7th Heaven
# 3              1928                       ACTRESS          A Ship Comes In
# 4              1928                       ACTRESS           Sadie Thompson
# ...             ...                           ...                      ...
# 1823           2024  ACTRESS IN A SUPPORTING ROLE                   Barbie
# 1824           2024  ACTRESS IN A SUPPORTING ROLE                     Nyad
# 1825           2024  ACTRESS IN A SUPPORTING ROLE              Oppenheimer
# 1826           2024  ACTRESS IN A SUPPORTING ROLE  The Color Purple (2023)
# 1827           2024  ACTRESS IN A SUPPORTING ROLE            The Holdovers
#
#                       name  year_film
# 0            Emil Jannings       <NA>
# 1      Richard Barthelmess       <NA>
# 2             Janet Gaynor       1927
# 3           Louise Dresser       1927
# 4           Gloria Swanson       <NA>
# ...                    ...        ...
# 1823       America Ferrera       2023
# 1824          Jodie Foster       2023
# 1825           Emily Blunt       2023
# 1826       Danielle Brooks       <NA>
# 1827  Da'Vine Joy Randolph       <NA>
#
# [1828 rows x 5 columns]

# %%
pd.merge(nominations, movies, on='film', how='right')
# Out:
#       year_ceremony                 category                         film  \
# 0              <NA>                     <NA>              $1,000 a Minute
# 1              <NA>                     <NA>                         '38'
# 2              <NA>                     <NA>           'Crocodile' Dundee
# 3              1987  ACTOR IN A LEADING ROLE              'Round Midnight
# 4              <NA>                     <NA>    (A) Torzija [(A) Torsion]
# ...             ...                      ...                          ...
# 5757           <NA>                     <NA>                     Zus & Zo
# 5758           2022  ACTOR IN A LEADING ROLE           tick, tick...BOOM!
# 5759           <NA>                     <NA>            À Nous la Liberté
# 5760           <NA>                     <NA>                   Ådalen '31
# 5761           <NA>                     <NA>  Éramos Pocos (One Too Many)
#
#                  name  year_film
# 0                <NA>       1935
# 1                <NA>       1986
# 2                <NA>       1986
# 3       Dexter Gordon       1986
# 4                <NA>       2003
# ...               ...        ...
# 5757             <NA>       2002
# 5758  Andrew Garfield       2021
# 5759             <NA>       1931
# 5760             <NA>       1969
# 5761             <NA>       2006
#
# [5762 rows x 5 columns]

# %%
nominations = pd.merge(nominations, movies, on='film')

# %%
nominations.value_counts('name').head(10)
# Out:
# name
# Meryl Streep         21
# Katharine Hepburn    12
# Jack Nicholson       12
# Bette Davis          11
# Paul Newman           9
# Spencer Tracy         9
# Al Pacino             9
# Laurence Olivier      9
# Denzel Washington     9
# Robert De Niro        8
# Name: count, dtype: int64

# %%
awards = pd.read_csv('awards.csv', dtype_backend='pyarrow')

# %%
awards.head()
# Out:
#    year_film  year_ceremony        category              film  \
# 0       1927           1928           ACTOR  The Last Command
# 1       1927           1928         ACTRESS        7th Heaven
# 2       1927           1928   ART DIRECTION   The Dove (1927)
# 3       1927           1928  CINEMATOGRAPHY           Sunrise
# 4       1927           1928  CINEMATOGRAPHY           Sunrise
#
#                       name
# 0            Emil Jannings
# 1             Janet Gaynor
# 2  William Cameron Menzies
# 3              Karl Struss
# 4           Charles Rosher

# %%
awards[awards.name == 'Meryl Streep']
# Out:
#       year_film  year_ceremony                      category  \
# 1113       1979           1980  ACTRESS IN A SUPPORTING ROLE
# 1179       1982           1983     ACTRESS IN A LEADING ROLE
# 1864       2011           2012     ACTRESS IN A LEADING ROLE
#
#                    film          name
# 1113  Kramer vs. Kramer  Meryl Streep
# 1179    Sophie's Choice  Meryl Streep
# 1864      The Iron Lady  Meryl Streep

# %%
awards.value_counts('name').head(10)
# Out:
# name
# Walt Disney, Producer                                                           22
# Metro-Goldwyn-Mayer                                                             12
# Italy                                                                           10
# France                                                                           9
# Warner Bros.                                                                     7
# Alfred Newman                                                                    7
# Gordon Hollingshead, Producer                                                    6
# Paramount                                                                        5
# Edward Selzer, Producer                                                          5
# Metro-Goldwyn-Mayer Studio Sound Department, Douglas Shearer, Sound Director     5
# Name: count, dtype: int64

# %%
pd.merge(nominations.value_counts('name'), awards.value_counts('name'), left_index=True, right_index=True).head(10)
# Out:
#                    count_x  count_y
# name
# Meryl Streep            21        3
# Katharine Hepburn       12        4
# Jack Nicholson          12        3
# Bette Davis             11        2
# Paul Newman              9        1
# Spencer Tracy            9        2
# Al Pacino                9        1
# Laurence Olivier         9        1
# Denzel Washington        9        2
# Robert De Niro           8        2

# %%
pd.concat([nominations.value_counts('name'), awards.value_counts('name')], axis=1).head(10)
# Out:
#                    count  count
# name
# Meryl Streep        21.0    3.0
# Katharine Hepburn   12.0    4.0
# Jack Nicholson      12.0    3.0
# Bette Davis         11.0    2.0
# Paul Newman          9.0    1.0
# Spencer Tracy        9.0    2.0
# Al Pacino            9.0    1.0
# Laurence Olivier     9.0    1.0
# Denzel Washington    9.0    2.0
# Robert De Niro       8.0    2.0

# %%
awards.film.value_counts()
# Out:
# film
# Ben-Hur                                              11
# Titanic (1997)                                       11
# The Lord of the Rings: The Return of the King        11
# West Side Story (1961)                               10
# Gigi                                                  9
#                                                      ..
# WAR IS OVER! Inspired by the Music of John & Yoko     1
# The Wonderful Story of Henry Sugar                    1
# Godzilla Minus One                                    1
# American Fiction                                      1
# Anatomy of a Fall                                     1
# Name: count, Length: 1343, dtype: int64[pyarrow]

# %%
pd.merge(awards, awards.film.value_counts(), left_on='film', right_index=True).query('count > 10')
# Out:
# /tmp/ipykernel_18999/3482463665.py:1: RuntimeWarning: Engine has switched to 'python' because numexpr does not support extension array dtypes. Please set your engine to python manually.
#   pd.merge(awards, awards.film.value_counts(), left_on='film', right_index=True).query('count > 10')
#       year_film  year_ceremony  \
# 638        1959           1960
# 639        1959           1960
# 643        1959           1960
# 644        1959           1960
# 646        1959           1960
# 648        1959           1960
# 649        1959           1960
# 652        1959           1960
# 654        1959           1960
# 659        1959           1960
# 660        1959           1960
# 1532       1997           1998
# 1533       1997           1998
# 1534       1997           1998
# 1535       1997           1998
# 1536       1997           1998
# 1539       1997           1998
# 1542       1997           1998
# 1544       1997           1998
# 1547       1997           1998
# 1548       1997           1998
# 1549       1997           1998
# 1675       2003           2004
# 1676       2003           2004
# 1678       2003           2004
# 1679       2003           2004
# 1682       2003           2004
# 1684       2003           2004
# 1685       2003           2004
# 1686       2003           2004
# 1690       2003           2004
# 1691       2003           2004
# 1692       2003           2004
#
#                                                category  \
# 638                                               ACTOR
# 639                          ACTOR IN A SUPPORTING ROLE
# 643                               ART DIRECTION (Color)
# 644                                 BEST MOTION PICTURE
# 646                              CINEMATOGRAPHY (Color)
# 648                              COSTUME DESIGN (Color)
# 649                                           DIRECTING
# 652                                        FILM EDITING
# 654   MUSIC (Music Score of a Dramatic or Comedy Pic...
# 659                                               SOUND
# 660                                     SPECIAL EFFECTS
# 1532                                      ART DIRECTION
# 1533                                       BEST PICTURE
# 1534                                     CINEMATOGRAPHY
# 1535                                     COSTUME DESIGN
# 1536                                          DIRECTING
# 1539                                       FILM EDITING
# 1542                    MUSIC (Original Dramatic Score)
# 1544                              MUSIC (Original Song)
# 1547                                              SOUND
# 1548                              SOUND EFFECTS EDITING
# 1549                                     VISUAL EFFECTS
# 1675                                      ART DIRECTION
# 1676                                       BEST PICTURE
# 1678                                     COSTUME DESIGN
# 1679                                          DIRECTING
# 1682                                       FILM EDITING
# 1684                                             MAKEUP
# 1685                             MUSIC (Original Score)
# 1686                              MUSIC (Original Song)
# 1690                                       SOUND MIXING
# 1691                                     VISUAL EFFECTS
# 1692                       WRITING (Adapted Screenplay)
#
#                                                film  \
# 638                                         Ben-Hur
# 639                                         Ben-Hur
# 643                                         Ben-Hur
# 644                                         Ben-Hur
# 646                                         Ben-Hur
# 648                                         Ben-Hur
# 649                                         Ben-Hur
# 652                                         Ben-Hur
# 654                                         Ben-Hur
# 659                                         Ben-Hur
# 660                                         Ben-Hur
# 1532                                 Titanic (1997)
# 1533                                 Titanic (1997)
# 1534                                 Titanic (1997)
# 1535                                 Titanic (1997)
# 1536                                 Titanic (1997)
# 1539                                 Titanic (1997)
# 1542                                 Titanic (1997)
# 1544                                 Titanic (1997)
# 1547                                 Titanic (1997)
# 1548                                 Titanic (1997)
# 1549                                 Titanic (1997)
# 1675  The Lord of the Rings: The Return of the King
# 1676  The Lord of the Rings: The Return of the King
# 1678  The Lord of the Rings: The Return of the King
# 1679  The Lord of the Rings: The Return of the King
# 1682  The Lord of the Rings: The Return of the King
# 1684  The Lord of the Rings: The Return of the King
# 1685  The Lord of the Rings: The Return of the King
# 1686  The Lord of the Rings: The Return of the King
# 1690  The Lord of the Rings: The Return of the King
# 1691  The Lord of the Rings: The Return of the King
# 1692  The Lord of the Rings: The Return of the King
#
#                                                    name  count
# 638                                     Charlton Heston     11
# 639                                       Hugh Griffith     11
# 643   Art Direction:  William A. Horning, Edward Car...     11
# 644                             Sam Zimbalist, Producer     11
# 646                                   Robert L. Surtees     11
# 648                                 Elizabeth Haffenden     11
# 649                                       William Wyler     11
# 652                   Ralph E. Winters, John D. Dunning     11
# 654                                        Miklos Rozsa     11
# 659   Metro-Goldwyn-Mayer Studio Sound Department, F...     11
# 660   Visual Effects by A. Arnold Gillespie, Robert ...     11
# 1532  Art Direction:  Peter Lamont;  Set Decoration:...     11
# 1533            James Cameron and Jon Landau, Producers     11
# 1534                                  Russell Carpenter     11
# 1535                                   Deborah L. Scott     11
# 1536                                      James Cameron     11
# 1539      Conrad Buff, James Cameron, Richard A. Harris     11
# 1542                                       James Horner     11
# 1544      Music by James Horner; Lyric by Will Jennings     11
# 1547  Gary Rydstrom, Tom Johnson, Gary Summers, Mark...     11
# 1548                    Tom Bellfort, Christopher Boyes     11
# 1549  Robert Legato, Mark Lasoff, Thomas L. Fisher, ...     11
# 1675  Art Direction: Grant Major; Set Decoration: Da...     11
# 1676  Barrie M. Osborne, Peter Jackson and Fran Wals...     11
# 1678                   Ngila Dickson and Richard Taylor     11
# 1679                                      Peter Jackson     11
# 1682                                      Jamie Selkirk     11
# 1684                      Richard Taylor and Peter King     11
# 1685                                       Howard Shore     11
# 1686  Music and Lyric by Fran Walsh and Howard Shore...     11
# 1690  Christopher Boyes, Michael Semanick, Michael H...     11
# 1691  Jim Rygiel, Joe Letteri, Randall William Cook ...     11
# 1692  Screenplay by Fran Walsh, Philippa Boyens & Pe...     11

# %%
acting = awards[awards.category.str.startswith('ACT')]

# %%
pd.merge(acting, acting.film.value_counts(), left_on='film', right_index=True).query('count > 1')
# Out:
# /tmp/ipykernel_18999/115540373.py:1: RuntimeWarning: Engine has switched to 'python' because numexpr does not support extension array dtypes. Please set your engine to python manually.
#   pd.merge(acting, acting.film.value_counts(), left_on='film', right_index=True).query('count > 1')
#       year_film  year_ceremony                      category  \
# 59         1934           1935                         ACTOR
# 60         1934           1935                       ACTRESS
# 134        1938           1939                       ACTRESS
# 135        1938           1939  ACTRESS IN A SUPPORTING ROLE
# 152        1939           1940                       ACTRESS
# ...         ...            ...                           ...
# 2126       2022           2023    ACTOR IN A SUPPORTING ROLE
# 2127       2022           2023     ACTRESS IN A LEADING ROLE
# 2128       2022           2023  ACTRESS IN A SUPPORTING ROLE
# 2149       2023           2024       ACTOR IN A LEADING ROLE
# 2150       2023           2024    ACTOR IN A SUPPORTING ROLE
#
#                                    film               name  count
# 59                It Happened One Night        Clark Gable      2
# 60                It Happened One Night  Claudette Colbert      2
# 134                             Jezebel        Bette Davis      2
# 135                             Jezebel        Fay Bainter      2
# 152                  Gone with the Wind       Vivien Leigh      2
# ...                                 ...                ...    ...
# 2126  Everything Everywhere All at Once        Ke Huy Quan      3
# 2127  Everything Everywhere All at Once      Michelle Yeoh      3
# 2128  Everything Everywhere All at Once   Jamie Lee Curtis      3
# 2149                        Oppenheimer     Cillian Murphy      2
# 2150                        Oppenheimer  Robert Downey Jr.      2
#
# [85 rows x 6 columns]
