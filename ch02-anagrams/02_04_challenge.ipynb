# %% [markdown]
# # 02_04: CoderPad challenge

# %%
# Instructions

# %% [markdown]
# ## Find palindromes
#
# Palindromes are pairs of words that become each other when we reverse the order of their letters. Palindromes are also anagrams!
#
# **Your task**: Write a function that returns all the palindromes in the dictionary of length 7 or above. You will work with the `anagrams_by_signature` dictionary.
#
# ### Parameters
#
# `anagrams_by_signature` as defined in video 02_03.
#
# ### Result
#
# A list of 2-sets containing all palindromic pairs consisting of words of length 7 or above.

# %%
# Answer

# %%
# Python code​​​​​​‌​‌​‌​​‌‌​‌​‌​‌​‌​‌‌‌‌​‌‌ below
# Use print("messages...") to debug your solution.

show_expected_result = True
show_hints = True

import itertools

def palindromes(anagrams_by_signature):
    # Your code goes here
    pals = []
    
    for signature, wordset in anagrams_by_signature.items():
        if len(signature) > 6:    
            for word1, word2 in itertools.combinations(wordset, 2):
                if word1 == word2[::-1]:
                    pals.append({word1, word2})
        
    return pals

# %%
anagrams_by_signature
# Out:
# {'aal': {'aal', 'ala'},
#  'aam': {'aam', 'ama'},
#  'aacinor': {'aaronic', 'nicarao', 'ocarina'},
#  'aaeinort': {'aaronite', 'aeration'},
#  'aaru': {'aaru', 'aura'},
#  'ab': {'ab', 'ba'},
#  'aab': {'aba', 'baa'},
#  'aabc': {'abac', 'caba'},
#  'aabcort': {'abactor', 'acrobat'},
#  'aabft': {'abaft', 'bafta'},
#  'aabelno': {'abalone', 'balonea'},
#  'aabdennor': {'abandoner', 'reabandon'},
#  'aabcin': {'abanic', 'bianca'},
#  'aabirs': {'abaris', 'arabis'},
#  'aabs': {'abas', 'saba'},
#  'aabers': {'abaser', 'abrase'},
#  'aabet': {'abate', 'ateba', 'batea', 'beata'},
#  'aabert': {'abater', 'artabe', 'eartab', 'trabea'},
#  'abb': {'abb', 'bab'},
#  'aabb': {'abba', 'baba'},
#  'abbey': {'abbey', 'bebay'},
#  'abby': {'abby', 'baby'},
#  'aabdt': {'abdat', 'batad'},
#  'abdeil': {'abdiel', 'baldie'},
#  'aaabdgiilmnnoov': {'abdominovaginal', 'vaginoabdominal'},
#  'aabcdeiilmnoosv': {'abdominovesical', 'vesicoabdominal'},
#  'abe': {'abe', 'bae', 'bea'},
# ...

# %%
# Test code

# %%
import pickle

# %%
pickle.dump(anagrams_by_signature, open('anagrams_by_signature.json', 'wb'))

# %%
import collections

words = sorted({line.strip().lower() for line in open('words.txt', 'r')})

def signature(word):
    return ''.join(sorted(word))

words_by_signature = collections.defaultdict(set)
for word in words:
    words_by_signature[signature(word)].add(word)

anagrams_by_signature = {sig: wordset for sig, wordset in words_by_signature.items() if len(wordset) > 1}

palindromes(anagrams_by_signature)
# Out:
# [{'amaroid', 'diorama'},
#  {'anacara', 'aracana'},
#  {'artamus', 'sumatra'},
#  {'dessert', 'tressed'},
#  {'leveler', 'relevel'},
#  {'redrawer', 'rewarder'},
#  {'rotanev', 'venator'}]

# %%
# Console output

# Hint: to reverse a string, use slicing with negative step
# Hint: you can use itertools.combinations(wordset, 2) to get all unique pairs from a list or set

# %%
palindromes()
# Out:
# [{'amaroid', 'diorama'},
#  {'anacara', 'aracana'},
#  {'artamus', 'sumatra'},
#  {'dessert', 'tressed'},
#  {'leveler', 'relevel'},
#  {'redrawer', 'rewarder'},
#  {'rotanev', 'venator'}]

# %% [markdown]
# Note:
# * amaroid is imitation amber
# * anacara is a fish
# * aracana is a fruit
# * artamus is a bird
# * rotanev may be a name
# * venator is latin for hunter

# %%
# Use print("messages...") to debug your solution.

show_expected_result = False
show_hints = False

def palindromes(anagrams_by_signature):
    # Your code goes here
        
    return []

# %%
import random
# Instructor Notes:
# Write test code that verifies the learners proposed answer
# You can write one or more test cases

# Only the lines of code between DISPLAY_BEGIN and DISPLAY_END
# are shown to the learner. The learner can change the visible
# code to try different test cases.

# Write your setup and testing code outside the display area.

# To use the candidate's code, the Answer module must be imported
import Answer

# setup any necessary dependencies here

import pickle
anagrams_by_signature = pickle.load(open('/tmp/deps/anagrams/anagrams_by_signature.pkl', 'rb'))

# Keep the following section flush left for correct display to learner.

# ##DISPLAY_BEGIN##
# This is how your code will be called.
# Your answer should be the largest value in the numbers list.
# You can edit this code to try different testing cases.
result = Answer.palindromes(anagrams_by_signature)
# ##DISPLAY_END##

# The rest of your code is invisible to the learner.

# Return the correct result. This code is invisible to the learner.
# This code is your solution to the problem.
# You'll use it to test the learners answer in display_message()
def get_correct_result():
    return [{'amaroid', 'diorama'},
            {'anacara', 'aracana'},
            {'artamus', 'sumatra'},
            {'dessert', 'tressed'},
            {'leveler', 'relevel'},
            {'redrawer', 'rewarder'},
            {'rotanev', 'venator'}]

# Display a message. This code is invisible to the learner.
def display_message(result):
    # The learner can opt in to seeing hints
    # Hints are specific for your question
    # Please edit this array to provide helpful hints
    # for this question.

    # Break long hints at 50 characters and insert line feeds.
    hints = [
        "To reverse a string, use slicing with negative step.",
        "You can use itertools.combinations(wordset, 2) to get all unique pairs from a list or set."
    ]
 
    # Get the correct result.
    correct_result = get_correct_result()

    is_answer_correct = (sorted(result) == sorted(correct_result))

    # ####################################
    # Do not change code in display_message()
    # below this line!
    # ####################################
    # Displays messages depending on whether the
    # learner's result matches the correct result.

    # Use this divider to separate console messages
    # ** Do not change this string! **
    divider = "--- -- -- -- -- -- -- -- -- -- -- --"
    indent = "* "
    prompt_for_show_answer = "Set 'show_expected_result' to True to see the correct value."
    prompt_for_show_hints = "Set 'show_hints' to True to see a hint."

    # LinkedIn Learning standard messages
    # ** Do not edit the code here or the success message text **
    success_messages = [
 		"You did it! This result is exactly right.",
		"Another one solved!",
		"Correct",
		"Well done! You reached the expected result.",
		"That's right!",
		"Great work! You got the right answer.",
		"Correct! Marvelous work.",
		"That's it! You're getting good at this.",
		"Bravo! This is the correct answer."
	]
    
    # LinkedIn Learning standard messages
    # ** Do not edit the code here or the fail message text **
    fail_messages = [
        "You didn't get it right this time. Ready to try again?",
		"Hmm, that's not quite right.\nTry taking another look",
		"Incorrect. Try again",
		"That's not the expected result.",
		"Something isn't working.",
		"Whoops, that's not it!\nConsider revisiting the question.",
		"You didn't get the correct answer this time.\nTime for another try.",
		"Incorrect. Revisit the question "
    ]

    if(is_answer_correct):
        message_number = random.randint(0, len(success_messages) - 1)
        print(success_messages[message_number])
    else:
        message_number = random.randint(0, len(fail_messages) - 1)
        print(fail_messages[message_number])

    print(f"Your code returned: {result}")
    print(divider)

    if not is_answer_correct:
        print("Need Help?")

        if Answer.show_expected_result:
            print(f"Expected result: {correct_result}")
        else:
            print(f"{indent}{prompt_for_show_answer}")
        
        if Answer.show_hints:
            hint_number = random.randint(0, len(hints) - 1)
            print(f"Hint: {hints[hint_number]}")
        else:
            print(f"{indent}{prompt_for_show_hints}")

display_message(result)

# %%
# Add functions to this file, one for each method defined in
# the Validators array below.

# Use assert (condition) to validate/unvalidate the candidate's answer which is
# in the Answer module (which you have to import)
import Answer
import pickle

anagrams_by_signature = pickle.load(open('/tmp/deps/anagrams/anagrams_by_signature.pkl', 'rb'))

def validate():
    result = [{'amaroid', 'diorama'},
              {'anacara', 'aracana'},
              {'artamus', 'sumatra'},
              {'dessert', 'tressed'},
              {'leveler', 'relevel'},
              {'redrawer', 'rewarder'},
              {'rotanev', 'venator'}]

    assert(sorted(Answer.palindromes(anagrams_by_signature)) == sorted(result))
